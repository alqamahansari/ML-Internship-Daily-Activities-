# %% [markdown]
# # Pandas

# %%
import pandas as pd 
import numpy as np
pd.__version__ # know the pandas version
# Out:
# '2.2.3'

# %%
s=pd.Series([1,2,3,]) # one column
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df=pd.DataFrame({
    "name": ["Alice","Bob"],
    "age":[12,34]})
df
# Out:
#     name  age
# 0  Alice   12
# 1    Bob   34

# %% [markdown]
# ## Reading data

# %%
df=pd.read_csv(r"C:\Resource\Sample data\people_data.csv")
df
# Out:
#        Name  Age       City
# 0     Alice   25  Hyderabad
# 1       Bob   30  Bengaluru
# 2   Charlie   28    Chennai
# 3     David   35  Hyderabad
# 4       Eve   22       Pune
# 5     Frank   40      Delhi
# 6     Grace   27  Bengaluru
# 7    Hannah   24    Chennai
# 8      Ivan   32       Pune
# 9      Judy   29  Hyderabad
# 10    Kevin   34      Delhi
# 11    Laura   26  Bengaluru
# 12  Mallory   45    Chennai
# 13     Niaj   23       Pune
# 14   Olivia   31  Hyderabad

# %% [markdown]
# ## writing the data into files

# %%
df.to_csv('data.csv',index=False)

# %% [markdown]
# ## exploring data

# %%
df.head()
# Out:
#       Name  Age       City
# 0    Alice   25  Hyderabad
# 1      Bob   30  Bengaluru
# 2  Charlie   28    Chennai
# 3    David   35  Hyderabad
# 4      Eve   22       Pune

# %%
df.tail()
# Out:
#        Name  Age       City
# 10    Kevin   34      Delhi
# 11    Laura   26  Bengaluru
# 12  Mallory   45    Chennai
# 13     Niaj   23       Pune
# 14   Olivia   31  Hyderabad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    15 non-null     object
#  1   Age     15 non-null     int64
#  2   City    15 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 492.0+ bytes

# %%
df['Name'][df['Age']=='Laura']
# Out:
# Series([], Name: Name, dtype: object)

# %%
df.shape
# Out:
# (15, 3)

# %%
df[2:5]
# Out:
#       Name  Age       City
# 2  Charlie   28    Chennai
# 3    David   35  Hyderabad
# 4      Eve   22       Pune

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.Name
# Out:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4         Eve
# 5       Frank
# 6       Grace
# 7      Hannah
# 8        Ivan
# 9        Judy
# 10      Kevin
# 11      Laura
# 12    Mallory
# 13       Niaj
# 14     Olivia
# Name: Name, dtype: object

# %%
df.Age
# Out:
# 0     25
# 1     30
# 2     28
# 3     35
# 4     22
# 5     40
# 6     27
# 7     24
# 8     32
# 9     29
# 10    34
# 11    26
# 12    45
# 13    23
# 14    31
# Name: Age, dtype: int64

# %%
df[['Name','Age']]
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2   Charlie   28
# 3     David   35
# 4       Eve   22
# 5     Frank   40
# 6     Grace   27
# 7    Hannah   24
# 8      Ivan   32
# 9      Judy   29
# 10    Kevin   34
# 11    Laura   26
# 12  Mallory   45
# 13     Niaj   23
# 14   Olivia   31

# %%
df.City
# Out:
# 0     Hyderabad
# 1     Bengaluru
# 2       Chennai
# 3     Hyderabad
# 4          Pune
# 5         Delhi
# 6     Bengaluru
# 7       Chennai
# 8          Pune
# 9     Hyderabad
# 10        Delhi
# 11    Bengaluru
# 12      Chennai
# 13         Pune
# 14    Hyderabad
# Name: City, dtype: object

# %%
df['Name'].max()
# Out:
# 'Olivia'

# %%
df['Name'].min()
# Out:
# 'Alice'

# %%
df['Age'].mean()
# Out:
# np.float64(30.066666666666666)

# %%
df['Age'].mode()
# Out:
# 0     22
# 1     23
# 2     24
# 3     25
# 4     26
# 5     27
# 6     28
# 7     29
# 8     30
# 9     31
# 10    32
# 11    34
# 12    35
# 13    40
# 14    45
# Name: Age, dtype: int64

# %%
df['Name'].describe()
# Out:
# count        15
# unique       15
# top       Alice
# freq          1
# Name: Name, dtype: object

# %%
df[df.Name==df.Name.max()]
# Out:
#       Name  Age       City
# 14  Olivia   31  Hyderabad

# %%
df.Age[df.Name==df.Name.max()]
# Out:
# 14    31
# Name: Age, dtype: int64
